# %%
from time import time
from multiprocessing import Pool, cpu_count
import tqdm  # show multi-processing progress bar

import pandas as pd

import mojo_api

# for auto reload a module after editing.
# %load_ext autoreload
# %autoreload 2

# %%
df = pd.DataFrame()
year_start = 2014
year_end = 2019
for year in range(year_start - 1, year_end + 1):
    year_df = mojo_api.get_movie_list(year)
    year_df.to_csv('./data/_movie_list_{}.csv'.format(year), index=False)
    print("Finished collecting movie list of {}, movie number: {}".format(year, year_df.shape[0]))
    df = pd.concat([df, year_df])
# Out:
# Finished collecting movie list of 2013, movie number: 802
# Finished collecting movie list of 2014, movie number: 808
# Finished collecting movie list of 2015, movie number: 803
# Finished collecting movie list of 2016, movie number: 811
# Finished collecting movie list of 2017, movie number: 816
# Finished collecting movie list of 2018, movie number: 908
# Finished collecting movie list of 2019, movie number: 833

# %%
# A movie title can appear across two years. Need to remove duplicate.
df_remove_dup = df.groupby('Title').agg({
    'Year': 'first',
    'Rank': 'first',
    'Title': 'first'
})
top = 150
df_remove_dup = df_remove_dup.sort_values(['Year', 'Rank'])
df_remove_dup = df_remove_dup[df_remove_dup['Year'] >= year_start]
df_remove_dup = df_remove_dup[df_remove_dup['Rank'] <= top]
df_remove_dup.to_csv('./data/_movie_list_all.csv', index=False)

# %%
df = pd.read_csv('./data/_movie_list_all.csv')
df['tt_id'] = None
df['rl_id'] = None
df['release_date'] = None
df['company'] = None
df['mpaa'] = None
df['genres'] = None
df['director'] = None
df['actors'] = None
df['budget'] = None
df['bo_opening'] = None
df['bo_gross'] = None
df['imdb_score'] = None

# %%
def add_info_chunk(df):
    for i in range(df.shape[0]):
        title = df['Title'].iloc[i]
        year = df['Year'].iloc[i]
        movie = mojo_api.Movie()
        movie.get_train_movie_info(title, year)
        df.loc[i, 'tt_id'] = movie.tt_id
        df.loc[i, 'rl_id'] = movie.rl_id
        df.loc[i, 'release_date'] = movie.release_date
        df.loc[i, 'company'] = movie.company
        df.loc[i, 'mpaa'] = movie.mpaa
        df.loc[i, 'genres'] = movie.genres
        df.loc[i, 'director'] = movie.director
        df.loc[i, 'actors'] = movie.actors
        df.loc[i, 'budget'] = movie.budget
        df.loc[i, 'bo_opening'] = movie.bo_opening
        df.loc[i, 'bo_gross'] = movie.bo_gross
        df.loc[i, 'imdb_score'] = movie.imdb_score
#     print(i, movie.title)
    return df

time_start = time()
with Pool(cpu_count()) as p:
    total = top #df.shape[1]
    chunks = list(tqdm.tqdm(
                p.imap(add_info_chunk, [df[df['Rank'] == i].reset_index(drop=True) for i in range(1, top+1)]), total=total))
time_end = time()
time_run = (time_end - time_start) / 60
print("Finished. Time: {0:.1f} min.".format(time_run))
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
#
#
#
#   1%|          | 1/150 [00:25<1:04:28, 25.96s/it]
#
#
#
#   3%|▎         | 5/150 [00:43<47:05, 19.48s/it]
# Finished. Time: 0.7 min.

# %%
df_filled = pd.DataFrame()
for chunk in chunks:
    df_filled = pd.concat([df_filled, chunk])
df_filled = df_filled.sort_values(['Year', 'Rank'])
df_filled = df_filled.reset_index(drop=True)

# %%
df_filled.head(40)
# Out:
#     Year  Rank                                       Title      tt_id  \
# 0   2014     1                     Guardians of the Galaxy  tt2015381
# 1   2014     2       The Hunger Games: Mockingjay - Part 1  tt1951265
# 2   2014     3         Captain America: The Winter Soldier  tt1843866
# 3   2014     4                              The Lego Movie  tt1490017
# 4   2014     5             Transformers: Age of Extinction  tt2109248
# 5   2015     1                              Jurassic World  tt0369610
# 6   2015     2  Star Wars: Episode VII - The Force Awakens  tt2488496
# 7   2015     3                     Avengers: Age of Ultron  tt2395427
# 8   2015     4                                  Inside Out  tt2096673
# 9   2015     5                                   Furious 7  tt2820852
# 10  2016     1                                Finding Dory  tt2277860
# 11  2016     2                Rogue One: A Star Wars Story  tt3748528
# 12  2016     3                  Captain America: Civil War  tt3498820
# 13  2016     4                     The Secret Life of Pets  tt2709768
# 14  2016     5                             The Jungle Book  tt3040964
# 15  2017     1     Star Wars: Episode VIII - The Last Jedi  tt2527336
# 16  2017     2                        Beauty and the Beast  tt2771200
# 17  2017     3                                Wonder Woman  tt0451279
# 18  2017     4              Guardians of the Galaxy Vol. 2  tt3896198
# 19  2017     5                      Spider-Man: Homecoming  tt2250912
# 20  2018     1                               Black Panther  tt1825683
# 21  2018     2                      Avengers: Infinity War  tt4154756
# 22  2018     3                               Incredibles 2  tt3606756
# 23  2018     4              Jurassic World: Fallen Kingdom  tt4881806
# 24  2018     5                                  Deadpool 2  tt5463162
# 25  2019     1                           Avengers: Endgame  tt4154796
# 26  2019     2                               The Lion King  tt6105098
# 27  2019     3                                 Toy Story 4  tt1979376
# 28  2019     4                                   Frozen II  tt4520988
# 29  2019     5                              Captain Marvel  tt4154664
#
#            rl_id release_date                              company   mpaa  \
# 0   rl3177416193   2014-08-01  Walt Disney Studios Motion Pictures  PG-13
# 1   rl4283991553   2014-11-21                            Lionsgate  PG-13
# 2   rl3194193409   2014-04-04  Walt Disney Studios Motion Pictures  PG-13
# 3    rl643728897   2014-02-07                         Warner Bros.     PG
# 4   rl2960623105   2014-06-27                   Paramount Pictures  PG-13
# 5   rl2371716609   2015-06-12                   Universal Pictures  PG-13
# 6   rl2691925505   2015-12-18  Walt Disney Studios Motion Pictures  PG-13
# 7    rl675644929   2015-05-01  Walt Disney Studios Motion Pictures  PG-13
# 8   rl4016604673   2015-06-19  Walt Disney Studios Motion Pictures     PG
# 9   rl1045661185   2015-04-03                   Universal Pictures  PG-13
# 10  rl3764946433   2016-06-17  Walt Disney Studios Motion Pictures     PG
# 11  rl2557707777   2016-12-16  Walt Disney Studios Motion Pictures  PG-13
# 12  rl3210970625   2016-05-06  Walt Disney Studios Motion Pictures  PG-13
# 13  rl2069595649   2016-07-08                   Universal Pictures     PG
# 14  rl2455602689   2016-04-15  Walt Disney Studios Motion Pictures     PG
# 15  rl2708702721   2017-12-15  Walt Disney Studios Motion Pictures  PG-13
# 16   rl222594561   2017-03-17  Walt Disney Studios Motion Pictures     PG
# 17   rl578455041   2017-06-02                         Warner Bros.  PG-13
# 18  rl2976089601   2017-05-05  Walt Disney Studios Motion Pictures  PG-13
# 19   rl863208961   2017-07-07              Sony Pictures Releasing  PG-13
# 20  rl2992866817   2018-02-16  Walt Disney Studios Motion Pictures  PG-13
# 21  rl3043198465   2018-04-27  Walt Disney Studios Motion Pictures  PG-13
# 22  rl2071758337   2018-06-15  Walt Disney Studios Motion Pictures     PG
# 23  rl1602061825   2018-06-22                   Universal Pictures  PG-13
# 24  rl2488436225   2018-05-18                Twentieth Century Fox      R
# 25  rl3059975681   2019-04-26  Walt Disney Studios Motion Pictures  PG-13
# 26  rl3321923073   2019-07-19  Walt Disney Studios Motion Pictures     PG
# 27  rl3798500865   2019-06-21  Walt Disney Studios Motion Pictures      G
# 28  rl2424210945   2019-11-22  Walt Disney Studios Motion Pictures     PG
# 29  rl3009644033   2019-03-08  Walt Disney Studios Motion Pictures  PG-13
#
#                                                genres            director  \
# 0                      Action,Adventure,Comedy,Sci-Fi          James Gunn
# 1                    Action,Adventure,Sci-Fi,Thriller    Francis Lawrence
# 2                    Action,Adventure,Sci-Fi,Thriller       Anthony Russo
# 3    Action,Adventure,Animation,Comedy,Family,Fantasy  Christopher Miller
# 4                             Action,Adventure,Sci-Fi         Michael Bay
# 5                             Action,Adventure,Sci-Fi     Colin Trevorrow
# 6                             Action,Adventure,Sci-Fi         J.J. Abrams
# 7                             Action,Adventure,Sci-Fi         Joss Whedon
# 8     Adventure,Animation,Comedy,Drama,Family,Fantasy         Pete Docter
# 9                           Action,Adventure,Thriller           James Wan
# 10                  Adventure,Animation,Comedy,Family      Andrew Stanton
# 11                            Action,Adventure,Sci-Fi      Gareth Edwards
# 12                            Action,Adventure,Sci-Fi       Anthony Russo
# 13                  Adventure,Animation,Comedy,Family        Chris Renaud
# 14                     Adventure,Drama,Family,Fantasy         Jon Favreau
# 15                    Action,Adventure,Fantasy,Sci-Fi        Rian Johnson
# 16                     Family,Fantasy,Musical,Romance         Bill Condon
# 17                Action,Adventure,Fantasy,Sci-Fi,War       Patty Jenkins
# 18                     Action,Adventure,Comedy,Sci-Fi          James Gunn
# 19                            Action,Adventure,Sci-Fi           Jon Watts
# 20                            Action,Adventure,Sci-Fi        Ryan Coogler
# 21                            Action,Adventure,Sci-Fi       Anthony Russo
# 22    Action,Adventure,Animation,Comedy,Family,Sci-Fi           Brad Bird
# 23                            Action,Adventure,Sci-Fi         J.A. Bayona
# 24                     Action,Adventure,Comedy,Sci-Fi        David Leitch
# 25                      Action,Adventure,Drama,Sci-Fi       Anthony Russo
# 26           Adventure,Animation,Drama,Family,Musical         Jon Favreau
# 27          Adventure,Animation,Comedy,Family,Fantasy         Josh Cooley
# 28  Adventure,Animation,Comedy,Family,Fantasy,Musical          Chris Buck
# 29                            Action,Adventure,Sci-Fi          Anna Boden
#
#                                 actors budget bo_opening bo_gross imdb_score
# 0               Chris Pratt,Vin Diesel    170    94.3209  333.177          8
# 1    Jennifer Lawrence,Josh Hutcherson    125    121.898  337.136        6.6
# 2        Chris Evans,Samuel L. Jackson    170    95.0237  259.767        7.7
# 3             Chris Pratt,Will Ferrell     60    69.0503  257.761        7.7
# 4           Mark Wahlberg,Nicola Peltz    210    100.038  245.439        5.6
# 5      Chris Pratt,Bryce Dallas Howard    150    208.806  652.271          7
# 6             Daisy Ridley,John Boyega    245    247.967  936.662        7.9
# 7        Robert Downey Jr.,Chris Evans    250    191.271  459.006        7.3
# 8               Amy Poehler,Bill Hader    175    90.4403  356.462        8.1
# 9               Vin Diesel,Paul Walker    190    147.187  353.007        7.1
# 10       Ellen DeGeneres,Albert Brooks    200     135.06  486.296        7.3
# 11           Felicity Jones,Diego Luna    200    155.082  532.177        7.8
# 12       Chris Evans,Robert Downey Jr.    250    179.139  408.084        7.8
# 13         Louis C.K.,Eric Stonestreet     75    104.353  368.384        6.5
# 14              Neel Sethi,Bill Murray    175    103.261  364.001        7.4
# 15            Daisy Ridley,John Boyega    317     220.01  620.181          7
# 16             Emma Watson,Dan Stevens    160    174.751  504.014        7.1
# 17                Gal Gadot,Chris Pine    149    103.251  412.563        7.4
# 18             Chris Pratt,Zoe Saldana    200     146.51  389.813        7.6
# 19          Tom Holland,Michael Keaton    175    117.028  334.201        7.4
# 20  Chadwick Boseman,Michael B. Jordan    200    202.004   700.06        7.3
# 21   Robert Downey Jr.,Chris Hemsworth    321    257.698  678.815        8.5
# 22        Craig T. Nelson,Holly Hunter    200    182.688  608.582        7.6
# 23     Chris Pratt,Bryce Dallas Howard    170    148.025   417.72        6.2
# 24           Ryan Reynolds,Josh Brolin    110    125.507  318.491        7.7
# 25       Robert Downey Jr.,Chris Evans    356    357.115  858.373        8.4
# 26               Donald Glover,Beyoncé    260    191.771  543.638        6.9
# 27                 Tom Hanks,Tim Allen    200    120.908  434.038        7.8
# 28           Kristen Bell,Idina Menzel    150    130.263  477.374        6.9
# 29       Brie Larson,Samuel L. Jackson    160    153.433   426.83        6.9

# %%
df[df['Year'] == 2019].reset_index(drop=True)
# Out:
#      Year  Rank                            Title tt_id rl_id release_date  \
# 0    2019     1                Avengers: Endgame  None  None         None
# 1    2019     2                    The Lion King  None  None         None
# 2    2019     3                      Toy Story 4  None  None         None
# 3    2019     4                        Frozen II  None  None         None
# 4    2019     5                   Captain Marvel  None  None         None
# ..    ...   ...                              ...   ...   ...          ...
# 124  2019   145               The Dead Don't Die  None  None         None
# 125  2019   146                             Jexi  None  None         None
# 126  2019   147                     Run the Race  None  None         None
# 127  2019   149  The Current War: Director's Cut  None  None         None
# 128  2019   150                    Captive State  None  None         None
#
#     company  mpaa genres director actors budget bo_opening bo_gross imdb_score
# 0      None  None   None     None   None   None       None     None       None
# 1      None  None   None     None   None   None       None     None       None
# 2      None  None   None     None   None   None       None     None       None
# 3      None  None   None     None   None   None       None     None       None
# 4      None  None   None     None   None   None       None     None       None
# ..      ...   ...    ...      ...    ...    ...        ...      ...        ...
# 124    None  None   None     None   None   None       None     None       None
# 125    None  None   None     None   None   None       None     None       None
# 126    None  None   None     None   None   None       None     None       None
# 127    None  None   None     None   None   None       None     None       None
# 128    None  None   None     None   None   None       None     None       None
#
# [129 rows x 15 columns]

# %%
movie.year
# Out:
# 2019

# %%
ii = 202, "Unfriended" tt4680034 not correct
ii = 445, "The Great Wall" tt7535780 not correct
ii = 766, "Greta" tt9477532
# Out:
# https://www.imdb.com/search/title/?title=Lone%20Survivor&release_date=2014-01-01,2014-12-31
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-ae7ba1786e36> in <module>
#       5 imdb_url = "https://www.imdb.com/search/title/?title={}&release_date={}-01-01,{}-12-31".format(title_url, movie.year, movie.year)
#       6 print(imdb_url)
# ----> 7 imdb_res = requests.get(imdb_url, headers=headers)
#       8 if imdb_res.status_code != 200:
#       9     print("Request Error. Code =", imdb_res.status_code)
#
# NameError: name 'headers' is not defined

# %%
df[~df['tt_id'].isnull()][df['budget'].isnull()]
# Out:
# /Users/zhao/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      Year  Rank                                      Title      tt_id  \
# 9    2014    10                   The Amazing Spider-Man 2  tt1872181
# 13   2014    14  The Hobbit: The Battle of the Five Armies  tt2310332
# 48   2014    53                                 Son of God  tt3210686
# 72   2014    78                                St. Vincent  tt2170593
# 75   2014    81                          The Expendables 3  tt2333784
# ..    ...   ...                                        ...        ...
# 776  2019   143                   Brittany Runs a Marathon  tt7671064
# 777  2019   145                         The Dead Don't Die  tt8695030
# 778  2019   146                                       Jexi  tt9354944
# 779  2019   147                               Run the Race  tt3201736
# 781  2019   150                              Captive State  tt5968394
#
#             rl_id release_date                  company   mpaa  \
# 9     rl846431745   2014-05-02  Sony Pictures Releasing  PG-13
# 13   rl2354677249   2014-12-17             Warner Bros.  PG-13
# 48   rl2574288385   2014-02-28    Twentieth Century Fox  PG-13
# 72   rl1282573825   2014-10-10    The Weinstein Company  PG-13
# 75   rl1448117761   2014-08-15                Lionsgate  PG-13
# ..            ...          ...                      ...    ...
# 776   rl705201665   2019-08-23           Amazon Studios      R
# 777  rl3960047105   2019-06-14           Focus Features      R
# 778  rl3423110657   2019-10-11                Lionsgate      R
# 779   rl738625025   2019-02-22     Roadside Attractions     PG
# 781   rl453215745   2019-03-15           Focus Features  PG-13
#
#                                                 genres             director  \
# 9                              Action,Adventure,Sci-Fi            Marc Webb
# 13                                   Adventure,Fantasy        Peter Jackson
# 48                             Biography,Drama,History  Christopher Spencer
# 72                                        Comedy,Drama       Theodore Melfi
# 75                           Action,Adventure,Thriller       Patrick Hughes
# ..                                                 ...                  ...
# 776                                       Comedy,Drama  Paul Downs Colaizzo
# 777                       Comedy,Fantasy,Horror,Sci-Fi         Jim Jarmusch
# 778                                             Comedy            Jon Lucas
# 779                                        Drama,Sport        Chris Dowling
# 781  Action,Adventure,Drama,Horror,Mystery,Sci-Fi,T...         Rupert Wyatt
#
#                                     actors budget bo_opening   bo_gross  \
# 9          Andrew Garfield,Andrew Garfield   None   91608337  202853933
# 13               Ian McKellen,Ian McKellen   None   54724334  255119788
# 48             Diogo Morgado,Diogo Morgado   None   25601865   59700064
# 72                 Bill Murray,Bill Murray   None     109878   44137712
# 75   Sylvester Stallone,Sylvester Stallone   None   15879645   39322544
# ..                                     ...    ...        ...        ...
# 776              Jillian Bell,Jillian Bell   None     180711    7189808
# 777                Bill Murray,Bill Murray   None    2540240    6563605
# 778                Adam Devine,Adam Devine   None    3106730    6546159
# 779              Tanner Stine,Tanner Stine   None    2161480    6424420
# 781              John Goodman,John Goodman   None    3131525    5958315
#
#     imdb_score
# 9          6.6
# 13         7.4
# 48         5.7
# 72         7.2
# 75         6.1
# ..         ...
# 776        6.8
# 777        5.5
# 778        6.1
# 779          6
# 781          6
#
# [162 rows x 15 columns]
