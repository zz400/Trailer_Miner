# %%
"""
Memo:

1. additional features: 
- title length
- Budget (converted to 2019 USD using the Consumer Price Index)
  https://fred.stlouisfed.org/series/CPIAUCNS
- Runtime (in minutes)
- Release date (month and year are treated as separate features)
- is 1st week holiday? is 2nd week holiday?
- Genre (23 categories and each movie can have multiple categories)
- Actors (names of the top-4-billed actors)
- Director
- MPAA rating (e.g., PG-13)
- Sequel or part of a franchise (Yes/No)

- actor starpower, director starpower

- ratio of two features. e.g.: budget_to_mean_year

2. target: bo_opening, or bo_opening / budget
2. check model with less features.
3. bo_opening much smaller than bo_gross for some movies. 
"""

# %%
import collections
from time import time
from multiprocessing import Pool, cpu_count
import tqdm  # show multi-processing progress bar

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import datetime
import calendar

# for auto reload a module after editing.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load data

# %%
file = "./data/metadata_2014-2019.csv"
df = pd.read_csv(file)
with open("./data/excluded_movies.txt", "r") as f:
    excluded_movies = f.read().split('\n')
df = df[~df['Title'].isin(excluded_movies)]

# %%
f_company_list = "./data/feature_company_list.txt"
f_mpaa_list = "./data/feature_mpaa_list.txt"
f_genre_list = "./data/feature_genre_list.txt"
f_director_list = "./data/feature_director_list.txt"
f_actor_list = "./data/feature_actor_list.txt"

# %% [markdown]
# ### 1.1 Company

# %%
company_count = collections.Counter(df.company)
print("Total companies: {}.".format(len(company_count)))
company_count.most_common(30)
# Out:
# Total companies: 43.
# [('Warner Bros.', 106),
#  ('Universal Pictures', 93),
#  ('Lionsgate', 76),
#  ('Twentieth Century Fox', 76),
#  ('Walt Disney Studios Motion Pictures', 58),
#  ('Paramount Pictures', 58),
#  ('Sony Pictures Releasing', 56),
#  ('STX Entertainment', 26),
#  ('Focus Features', 22),
#  ('Screen Gems', 18),
#  ('Open Road Films (II)', 18),
#  ('Fox Searchlight Pictures', 16),
#  ('The Weinstein Company', 12),
#  ('TriStar Pictures', 11),
#  ('Relativity Media', 11),
#  ('A24', 10),
#  ('Roadside Attractions', 9),
#  ('United Artists Releasing', 6),
#  ('Pure Flix Entertainment', 5),
#  ('BH Tilt', 5),
#  ('Broad Green Pictures', 4),
#  ('Aviron Pictures', 4),
#  ('Metro-Goldwyn-Mayer (MGM)', 4),
#  ('Freestyle Releasing', 3),
#  ('Bleecker Street Media', 3),
#  ('Entertainment Studios Motion Pictures', 3),
#  ('Annapurna Pictures', 3),
#  ('IFC Films', 2),
#  ('Clarius Entertainment', 2),
#  ('Dimension Films', 2)]

# %%
top = 15
top_items = [e[0] for e in company_count.most_common(top)]
with open(f_company_list, 'w') as f:
    for e in top_items:
        f.write(e + "\n")

# %% [markdown]
# ### 1.2 mpaa

# %%
mpaa_count = collections.Counter(df.mpaa)
print("Total mpaa: {}.".format(len(mpaa_count)))
mpaa_count.most_common()
# Out:
# Total mpaa: 5.
# [('PG-13', 326), ('R', 272), ('PG', 134), ('G', 5), (nan, 4)]

# %%
top = 4
top_items = [e[0] for e in mpaa_count.most_common(top)]
with open(f_mpaa_list, 'w') as f:
    for e in top_items:
        f.write(e + "\n")

# %% [markdown]
# ### 1.3 genres

# %%
genres_lists = list(df['genres'].apply(lambda x: [genre for genre in x.split(",")]))
genres_count = collections.Counter([i for genres_list in genres_lists for i in genres_list])
print("Total genre kinds: {}. Total genre tags: {}".format(len(genres_count), sum(genres_count.values())))
genres_count.most_common()
# Out:
# Total genre kinds: 21. Total genre tags: 2529
# [('Drama', 345),
#  ('Comedy', 283),
#  ('Action', 262),
#  ('Thriller', 251),
#  ('Adventure', 244),
#  ('Sci-Fi', 142),
#  ('Fantasy', 141),
#  ('Family', 126),
#  ('Crime', 120),
#  ('Mystery', 117),
#  ('Horror', 104),
#  ('Romance', 99),
#  ('Biography', 78),
#  ('Animation', 70),
#  ('History', 37),
#  ('Music', 29),
#  ('Musical', 25),
#  ('War', 23),
#  ('Sport', 22),
#  ('Western', 6),
#  ('Documentary', 5)]

# %%
top = 20
top_items = [e[0] for e in genres_count.most_common(top)]
with open(f_genre_list, 'w') as f:
    for e in top_items:
        f.write(e + "\n")

# %% [markdown]
# ### 1.4 director

# %%
director_count = collections.Counter(df.director)
print("Total director: {}.".format(len(director_count)))
director_count.most_common(30)
# Out:
# Total director: 538.
# [('Clint Eastwood', 5),
#  ('Tyler Perry', 5),
#  ('Anthony Russo', 4),
#  ('Tim Story', 4),
#  ('Antoine Fuqua', 4),
#  ('Jaume Collet-Serra', 4),
#  ('Ridley Scott', 4),
#  ('Sean Anders', 4),
#  ('Paul Feig', 4),
#  ('Deon Taylor', 4),
#  ('Francis Lawrence', 3),
#  ('Michael Bay', 3),
#  ('Bryan Singer', 3),
#  ('Nicholas Stoller', 3),
#  ('Wes Ball', 3),
#  ('David Ayer', 3),
#  ('Ben Falcone', 3),
#  ('Lasse Hallström', 3),
#  ('James Bobin', 3),
#  ('Kenneth Branagh', 3),
#  ('Chad Stahelski', 3),
#  ('Jake Kasdan', 3),
#  ('Christopher Landon', 3),
#  ('Jon Favreau', 3),
#  ('Mike Flanagan', 3),
#  ('Andrew Erwin', 3),
#  ('James Wan', 3),
#  ('F. Gary Gray', 3),
#  ('Steven Spielberg', 3),
#  ('M. Night Shyamalan', 3)]

# %%
top = 30
top_items = [e[0] for e in director_count.most_common(top)]
with open(f_director_list, 'w') as f:
    for e in top_items:
        f.write(e + "\n")

# %% [markdown]
# ### 1.5 actors

# %%
actors_lists = list(df['actors'].apply(lambda x: [actor for actor in x.split(",")]))
actors_count = collections.Counter([i for actors_list in actors_lists for i in actors_list])
print("Total actors: {}.".format(len(actors_count)))
actors_count.most_common(30)
# Out:
# Total actors: 841.
# [('Kevin Hart', 10),
#  ('Dwayne Johnson', 10),
#  ('Mark Wahlberg', 9),
#  ('Chris Pratt', 8),
#  ('Charlize Theron', 8),
#  ('Samuel L. Jackson', 7),
#  ('Matthew McConaughey', 7),
#  ('Melissa McCarthy', 7),
#  ('Kevin Costner', 7),
#  ('Ryan Reynolds', 7),
#  ('Chris Hemsworth', 7),
#  ('James McAvoy', 7),
#  ('Jennifer Lawrence', 6),
#  ('Chris Evans', 6),
#  ('Will Ferrell', 6),
#  ('Will Arnett', 6),
#  ('Shailene Woodley', 6),
#  ('Tom Cruise', 6),
#  ('Liam Neeson', 6),
#  ('Matt Damon', 6),
#  ('Jennifer Garner', 6),
#  ('Anna Kendrick', 6),
#  ('Jason Bateman', 6),
#  ('Robert Downey Jr.', 6),
#  ('Michael Keaton', 6),
#  ('Johnny Depp', 6),
#  ('Josh Brolin', 6),
#  ('Tom Hanks', 6),
#  ('Michael Fassbender', 6),
#  ('Vin Diesel', 5)]

# %%
top = 30
top_items = [e[0] for e in actors_count.most_common(top)]
with open(f_actor_list, 'w') as f:
    for e in top_items:
        f.write(e + "\n")

# %% [markdown]
# ### 1.6 release_date

# %%
release_weekday = list(df['release_date'].apply(lambda x: 
                        calendar.day_name[datetime.datetime.strptime(x, "%Y-%m-%d").weekday()]))
weekday_count = collections.Counter(release_weekday).most_common()
weekday_count
# Out:
# [('Friday', 670),
#  ('Wednesday', 57),
#  ('Thursday', 8),
#  ('Tuesday', 5),
#  ('Monday', 1)]

# %% [markdown]
# ### 2.1 budget, bo_gross, bo_opening, imdb_score

# %%
fig, ax = plt.subplots(figsize = (20, 6))
plt.subplot(1, 4, 1)
plt.hist(df['budget'], bins=50)
plt.title('Distribution of budget')
plt.subplot(1, 4, 2)
plt.hist(df['bo_gross'], bins=50)
plt.title('Distribution of bo_gross')
plt.subplot(1, 4, 3)
plt.hist(df['bo_opening'], bins=50)
plt.title('Distribution of bo_opening')
plt.subplot(1, 4, 4)
plt.hist(df['imdb_score'])
plt.title('Distribution of imdb_score')
# Out:
# Text(0.5, 1.0, 'Distribution of imdb_score')

# %% [markdown]
# ### 2.2  bo_gross vs budget, bo_opening vs budget, bo_opening vs bo_gross

# %%
x = 'budget'
y = 'bo_gross'
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(df[x], df[y])
plt.title('{} vs {}'.format(y, x))
plt.xlabel(x)
plt.ylabel(y)

plt.subplot(1, 2, 2)
plt.scatter(np.log1p(df[x]), np.log1p(df[y]))
plt.title('Log {} vs Log {}'.format(y, x))
plt.xlabel('Log ' + x)
plt.ylabel('Log ' + y)
# Out:
# Text(0, 0.5, 'Log bo_gross')

# %%
x = 'budget'
y = 'bo_opening'
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(df[x], df[y])
plt.title('{} vs {}'.format(y, x))
plt.xlabel(x)
plt.ylabel(y)

plt.subplot(1, 2, 2)
plt.scatter(np.log1p(df[x]), np.log1p(df[y]))
plt.title('Log {} vs Log {}'.format(y, x))
plt.xlabel('Log ' + x)
plt.ylabel('Log ' + y)
# Out:
# Text(0, 0.5, 'Log bo_opening')

# %%
x = 'bo_gross'
y = 'bo_opening'
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(df[x], df[y])
plt.title('{} vs {}'.format(y, x))
plt.xlabel(x)
plt.ylabel(y)

plt.subplot(1, 2, 2)
plt.scatter(np.log1p(df[x]), np.log1p(df[y]))
plt.title('Log {} vs Log {}'.format(y, x))
plt.xlabel('Log ' + x)
plt.ylabel('Log ' + y)
# Out:
# Text(0, 0.5, 'Log bo_opening')

# %%
x = 'budget'
y = 'imdb_score'
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(df[x], df[y])
plt.title('{} vs {}'.format(y, x))
plt.xlabel(x)
plt.ylabel(y)

x = 'bo_gross'
y = 'imdb_score'
plt.subplot(1, 2, 2)
plt.scatter(df[x], df[y])
plt.title('{} vs {}'.format(y, x))
plt.xlabel(x)
plt.ylabel(y)
# Out:
# Text(0, 0.5, 'imdb_score')
