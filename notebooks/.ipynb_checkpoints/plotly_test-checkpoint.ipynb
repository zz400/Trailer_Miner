# %%
# Get this figure: fig = py.get_figure("https://plotly.com/~bdew/121/")
# Get this figure's data: data = py.get_figure("https://plotly.com/~bdew/121/").get_data()
# Add data to this figure: py.plot(Data([Scatter(x=[1, 2], y=[2, 3])]), filename ="EPOPs and taxes_fig1", fileopt="extend")
# Get y data of first trace: y1 = py.get_figure("https://plotly.com/~bdew/121/").get_data()[0]["y"]

# Get figure documentation: https://plotly.com/python/get-requests/
# Add data documentation: https://plotly.com/python/file-options/

# If you're using unicode in your file, you may need to specify the encoding.
# You can reproduce this figure in Python with the following code!

# Learn about API authentication here: https://plotly.com/python/getting-started
# Find your api_key here: https://plotly.com/settings/api

import chart_studio
chart_studio.tools.set_credentials_file(username='zzyang', api_key='Xp2TeOUekHBkBBs5CGIy')
import chart_studio.plotly as py
import plotly.graph_objects as go
from plotly.graph_objects import *

# %%
# py.sign_in('username', 'api_key')
trace1 = {
  "fill": "tonexty", 
  "line": {
    "shape": "hv", 
    "width": 0
  }, 
  "mode": "lines", 
  "name": "Shaded region", 
#   "type": "scatter", 
#   "xsrc": "bdew:122:eb8874", 
  "x": ["1993-01-01", "2003",  "2012-01-01"], 
#   "ysrc": "bdew:122:4e2e22", 
  "y": [100, 0, 0], 
  "fillcolor": "rgba(135, 143, 135, 0.2)", 
  "hoverinfo": "none", 
  "showlegend": False
}
trace2 = {
  "line": {
    "color": "rgb(0, 0, 153)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "Men", 
  "type": "scatter", 
  "xsrc": "bdew:122:eb8874", 
  "x": ["1993-01-01", "1994-01-01", "1995-01-01", "1996-01-01", "1997-01-01", "1998-01-01", "1999-01-01", "2000-01-01", "2001-01-01", "2002-01-01", "2003-01-01", "2004-01-01", "2005-01-01", "2006-01-01", "2007-01-01", "2008-01-01", "2009-01-01", "2010-01-01", "2011-01-01", "2012-01-01"], 
  "ysrc": "bdew:122:1fadd6", 
  "y": [87.01666667, 87.24166667, 87.60833333, 87.925, 88.41666667, 88.83333333, 88.98333333, 88.99166667, 87.93333333, 86.60833333, 85.875, 86.34166667, 86.925, 87.30833333, 87.525, 86.03333333, 81.45833333, 80.95833333, 81.425, 82.53333333], 
  "opacity": 1, 
  "textsrc": "bdew:122:9c7a4e", 
  "text": ["Men: 1993: 87.0%", "Men: 1994: 87.2%", "Men: 1995: 87.6%", "Men: 1996: 87.9%", "Men: 1997: 88.4%", "Men: 1998: 88.8%", "Men: 1999: 89.0%", "Men: 2000: 89.0%", "Men: 2001: 87.9%", "Men: 2002: 86.6%", "Men: 2003: 85.9%", "Men: 2004: 86.3%", "Men: 2005: 86.9%", "Men: 2006: 87.3%", "Men: 2007: 87.5%", "Men: 2008: 86.0%", "Men: 2009: 81.5%", "Men: 2010: 81.0%", "Men: 2011: 81.4%", "Men: 2012: 82.5%"], 
  "visible": True, 
  "hoverinfo": "text", 
  "showlegend": False, 
  "connectgaps": False
}
trace3 = {
  "line": {
    "color": "rgb(0, 128, 255)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "Women", 
  "type": "scatter", 
  "xsrc": "bdew:122:eb8874", 
  "x": ["1993-01-01", "1994-01-01", "1995-01-01", "1996-01-01", "1997-01-01", "1998-01-01", "1999-01-01", "2000-01-01", "2001-01-01", "2002-01-01", "2003-01-01", "2004-01-01", "2005-01-01", "2006-01-01", "2007-01-01", "2008-01-01", "2009-01-01", "2010-01-01", "2011-01-01", "2012-01-01"], 
  "ysrc": "bdew:122:93d4ab", 
  "y": [70.36666667, 71.5, 72.19166667, 72.75833333, 73.54166667, 73.63333333, 74.15, 74.2, 73.425, 72.26666667, 72.01666667, 71.85, 71.98333333, 72.50833333, 72.5, 72.31666667, 70.21666667, 69.35, 68.975, 69.2], 
  "textsrc": "bdew:122:783ecd", 
  "text": ["Women: 1993: 70.4%", "Women: 1994: 71.5%", "Women: 1995: 72.2%", "Women: 1996: 72.8%", "Women: 1997: 73.5%", "Women: 1998: 73.6%", "Women: 1999: 74.2%", "Women: 2000: 74.2%", "Women: 2001: 73.4%", "Women: 2002: 72.3%", "Women: 2003: 72.0%", "Women: 2004: 71.8%", "Women: 2005: 72.0%", "Women: 2006: 72.5%", "Women: 2007: 72.5%", "Women: 2008: 72.3%", "Women: 2009: 70.2%", "Women: 2010: 69.4%", "Women: 2011: 69.0%", "Women: 2012: 69.2%"], 
  "hoverinfo": "text", 
  "showlegend": False
}
data = Data([trace1, trace2, trace3])
layout = {
  "font": {"family": "Balto"}, 
  "title": "", 
  "width": 500, 
  "xaxis": {
    "type": "date", 
    "range": ["1992-06-01", "2012-06-01"], 
    "ticks": "inside", 
    "title": "", 
    "nticks": 11, 
    "showgrid": False, 
    "tickfont": {"family": "Balto"}, 
    "autorange": False, 
    "fixedrange": True, 
    "ticksuffix": ""
  }, 
  "yaxis": {
    "type": "linear", 
    "dtick": 5, 
    "range": [65, 96], 
    "tick0": 0, 
    "ticks": "", 
    "title": "", 
    "showgrid": True, 
    "tickfont": {"family": "Balto"}, 
    "tickmode": "linear", 
    "autorange": False, 
    "fixedrange": True, 
    "ticksuffix": "%", 
    "showticklabels": True
  }, 
  "height": 400, 
#   "legend": {
#     "x": 0.681502859035, 
#     "y": 1.09189189189, 
#     "font": {"size": 12}, 
#     "traceorder": "normal", 
#     "orientation": "v"
#   }, 
#   "margin": {
#     "b": 70, 
#     "l": 40, 
#     "r": 10, 
#     "t": 50
#   }, 
  "autosize": False, 
  "hovermode": "x", 
  "titlefont": {
    "size": 16, 
    "family": "Balto"
  }, 
  "showlegend": True, 
  "annotations": [
#     {
#       "x": -0.036527039269, 
#       "y": -0.181328320802, 
#       "font": {
#         "size": 10, 
#         "family": "Open Sans, sans-serif"
#       }, 
#       "text": "http://cepr.net<br>Source: Bureau of Labor Statistics, labor force statistics from the current population survey.  ", 
#       "xref": "paper", 
#       "yref": "paper", 
#       "align": "left", 
#       "showarrow": False
#     }, 
#     {
#       "x": -0.03, 
#       "y": 1.15214285714, 
#       "font": {
#         "size": 15, 
#         "family": "Balto"
#       }, 
#       "text": "<b>Figure 1. Prime-age employment-to-population ratio (EPOP)<br> &nbsp;</b><i>Age 25-54, share of population that is employed</i>", 
#       "xref": "paper", 
#       "yref": "paper", 
#       "align": "left", 
#       "showarrow": False
#     }, 
    {
      "x": 0.09, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "text": "High-tax period", 
      "xref": "paper", 
      "yref": "paper", 
      "showarrow": False
    }, 
    {
      "x": 0.84, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "text": "Low-tax period", 
      "xref": "paper", 
      "yref": "paper", 
      "showarrow": False
    }, 
    {
      "x": 0.751111111111, 
      "y": 0.839285714286, 
      "font": {"size": 20}, 
      "text": "<b>Men</b>", 
      "xref": "paper", 
      "yref": "paper", 
      "showarrow": False
    }, 
    {
      "x": 0.792777777778, 
      "y": 0.247368421053, 
      "font": {"size": 20}, 
      "text": "&lt;b&gt;Women&lt;/b&gt;", 
      "xref": "paper", 
      "yref": "paper", 
      "showarrow": False
    }
  ], 
  "plot_bgcolor": "rgb(255, 252, 245)", 
  "paper_bgcolor": "rgb(255, 252, 245)"
}
fig = Figure(data=data, layout=layout)

# %%
py.iplot(fig)
# Out:
#         <iframe
#             width="500px"
#             height="400px"
#             src="https://plotly.com/~zzyang/193.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
